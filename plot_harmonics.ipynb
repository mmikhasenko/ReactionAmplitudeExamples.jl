# %%
using Plots

# %%
plotly()

# %%
using GSL
# Out:
# WARNING: both GSL and Base export "acosh"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "asinh"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "atanh"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "expm1"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "frexp"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "hypot"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "isinf"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "isnan"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "ldexp"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "log1p"; uses of it in module Main must be qualified
# WARNING: both GSL and Base export "permute"; uses of it in module Main must be qualified

# %%
?sf_legendre_Pl
# Out:
# search: sf_legendre_Pl sf_legendre_Plm sf_legendre_Pl_e sf_legendre_Plm_e
# No documentation found.
#
# `GSL.sf_legendre_Pl` is a `Function`.
#
# ```
# # 4 methods for generic function "sf_legendre_Pl":
# sf_legendre_Pl(l::Integer, x::Real) in GSL at /localhome/mikhasenko/.julia/v0.6/GSL/src/../src/_7_24_1_Legendre_Polynomials.jl:91
# sf_legendre_Pl(x::Number, y::AbstractArray{T1,N} where N) where T1<:Number in GSL at deprecated.jl:56
# sf_legendre_Pl(x::AbstractArray{T1,N} where N, y::Number) where T1<:Number in GSL at deprecated.jl:56
# sf_legendre_Pl(x::AbstractArray{T1,N} where N, y::AbstractArray{T2,N} where N) where {T1<:Number, T2<:Number} in GSL at deprecated.jl:56
# ```

# %%
plot(z->sf_legendre_Pl(3,z),-1,1)
# Out:
# <script src="file:///localhome/mikhasenko/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="a64d91f0-0064-4181-9158-72a80bd5b1e3" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('a64d91f0-0064-4181-9158-72a80bd5b1e3');
# ...

# %%
function f(z)
    θ = acos(z)
    sf_legendre_Pl(0,z)-0.3*sf_legendre_Pl(4,z)-0.2*sf_legendre_Pl(7,z)
end
# Out:
# f (generic function with 1 method)

# %%
pyplot()
# Out:
# INFO: Recompiling stale cache file /localhome/mikhasenko/.julia/lib/v0.6/PyPlot.ji for module PyPlot.
# WARNING: You are using Matplotlib 1.2.0, which is no longer officialy supported by the Plots community. To ensure smooth Plots.jl integration update your Matplotlib library to a version >= 2.0.0
# Plots.PyPlotBackend()

# %%
plot(xlab = "cos()", ylab = "Amplitude")
plot!(z->f(z), -1, 1, lw = 2, c = :black, lab = "data")
plot!(z->sf_legendre_Pl(0,z), -1, 1, lab = "spin 0")
plot!(z->0.3*sf_legendre_Pl(4,z), -1, 1, lab = "spin 4")
plot!(z->-0.2*sf_legendre_Pl(7,z), -1, 1, lab = "spin 7")
# Out:
# KeyError: key "set_axis_bgcolor" not found
#
# Stacktrace:
#  [1] getindex(::PyCall.PyObject, ::String) at /localhome/mikhasenko/.julia/v0.6/PyCall/src/PyCall.jl:247
#  [2] getindex(::PyPlot.Figure, ::Symbol) at /localhome/mikhasenko/.julia/v0.6/PyPlot/src/PyPlot.jl:67
#  [3] _before_layout_calcs(::Plots.Plot{Plots.PyPlotBackend}) at /localhome/mikhasenko/.julia/v0.6/Plots/src/backends/pyplot.jl:958
#  [4] prepare_output(::Plots.Plot{Plots.PyPlotBackend}) at /localhome/mikhasenko/.julia/v0.6/Plots/src/plot.jl:253
#  [5] show(::Base64EncodePipe, ::MIME{Symbol("image/png")}, ::Plots.Plot{Plots.PyPlotBackend}) at /localhome/mikhasenko/.julia/v0.6/Plots/src/output.jl:209
#  [6] base64encode(::Function, ::MIME{Symbol("image/png")}, ::Vararg{Any,N} where N) at ./base64.jl:197
#  [7] display_dict(::Plots.Plot{Plots.PyPlotBackend}) at /localhome/mikhasenko/.julia/v0.6/Plots/src/output.jl:293
# ...

# %%
plot(z->abs2(f(z)), -1, 1, lw = 2, c = :black)
plot!(z->abs2(sf_legendre_Pl(0,z)), -1, 1, lab = "spin 0")
plot!(z->abs2(0.3*sf_legendre_Pl(4,z)), -1, 1, lab = "spin 4")
plot!(z->abs2(-0.2*sf_legendre_Pl(7,z)), -1, 1, lab = "spin 7")
# Out:
# <script src="file:///localhome/mikhasenko/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="c43a5105-a3ee-4a66-979d-8c16bb2694cb" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('c43a5105-a3ee-4a66-979d-8c16bb2694cb');
# ...

# %%
plot(θ->f(cos(θ)), 0, π)
# Out:
# <script src="file:///localhome/mikhasenko/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="7c684fd5-f403-416b-a01d-7b8a1c8b3991" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('7c684fd5-f403-416b-a01d-7b8a1c8b3991');
# ...
