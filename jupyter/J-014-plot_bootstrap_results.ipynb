# %% [markdown]
# # Plotting results from the bootstrap studies

# %% [markdown]
# Read the data

# %%
data = readdlm("/run/media/mikhasenko/461D-4ABD/3pi_data/parameters.txt")
# Out:
# 100×9 Array{Float64,2}:
#  20.8644  0.77405   0.0444874  28.0262  …  -0.614213  6.75893    9.39003
#  19.8104  0.815098  0.383478   15.2141     -0.103543  7.81108    6.53722
#  17.1328  0.792139  0.469641   16.9307     -0.261261  4.56985    1.84118
#  20.0996  0.80454   0.534728   14.1114     -0.36703   8.08986   17.0346
#  19.9076  0.861484  0.433974   16.1426     -0.824624  2.49302    3.78464
#  16.897   0.811798  0.46521    14.065   …  -2.99357   1.146      3.09171
#  18.2929  0.795946  0.453768   16.2885     -0.121033  7.87566    5.0523
#  18.4446  0.805228  0.480877   13.1779     -0.281891  7.69061   12.1795
#  18.6224  0.817416  0.378302   16.8188     -0.212133  6.04779    6.39515
#  17.9776  0.808765  0.531995   15.5041     -2.41861   1.81727    2.96192
#  55.3337  0.632042  2.39477    17.7934  …  -3.59631   4.91384   25.3342
#  22.2776  0.764586  0.681468   17.3258     -0.622478  7.77362   24.6449
#  14.8922  0.785284  0.577939   13.0354     -5.25187   1.29699    2.96733
# ...

# %% [markdown]
# ### Parameters are numbered as
#  - [1] norm const
#  - [2] M1
#  - [3] G1
#  - [4] norm const
#  - [5] M2
#  - [6] $\Gamma_2$
#  - [7] c0
#  - [8] $m_0$
#  - [9] c1

# %% [markdown]
# Plot correlations

# %%
using Plots

# %%
scatter(data[:,2],data[:,3])
hline!([mean(data[:,2])])
vline!([mean(data[:,3])])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip5500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5500)" points="
# 22.3377,375.813 580.315,375.813 580.315,11.811 22.3377,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5502">
#     <rect x="22" y="11" width="559" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   127.753,375.813 127.753,11.811
#   "/>
# ...

# %%
plot(title = "Mass-Width correlation. Second resonance")
scatter!(data[:,5],data[:,6], xlab = "Mass (GeV)", ylab = "Width (GeV)", lab="")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip6300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6300)" points="
# 38.0857,355.846 580.315,355.846 580.315,31.4961 38.0857,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6302">
#     <rect x="38" y="31" width="543" height="325"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   106.649,355.846 106.649,31.4961
#   "/>
# ...

# %% [markdown]
# Save the last created plot to the `.pdf/.png` format

# %%
savefig("/tmp/test.pdf")
